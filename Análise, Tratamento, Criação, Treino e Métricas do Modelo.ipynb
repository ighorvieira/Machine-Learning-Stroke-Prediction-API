# %%
import pandas as pd

df=pd.read_csv('drive/MyDrive/Projeto Oficial Machine Learnig/healthcare-dataset-stroke-data.csv',sep=',', encoding='utf-8')
display(df.head())
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
display(df['smoking_status'].unique())
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
display(df['smoking_status'].value_counts())
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %%
display(df.describe())
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
for coluna in df.columns:
  print(df[coluna].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 201
# 0
# 0

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df=df.dropna()
display(df.describe())
# Out:
#                  id          age  hypertension  heart_disease  \
# count   4909.000000  4909.000000   4909.000000    4909.000000
# mean   37064.313506    42.865374      0.091872       0.049501
# std    20995.098457    22.555115      0.288875       0.216934
# min       77.000000     0.080000      0.000000       0.000000
# 25%    18605.000000    25.000000      0.000000       0.000000
# 50%    37608.000000    44.000000      0.000000       0.000000
# 75%    55220.000000    60.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        4909.000000  4909.000000  4909.000000
# mean          105.305150    28.893237     0.042575
# std            44.424341     7.854067     0.201917
# min            55.120000    10.300000     0.000000
# 25%            77.070000    23.500000     0.000000
# 50%            91.680000    28.100000     0.000000
# ...

# %%
df=df[df['gender'] != 'outhers']

# %%
df=df.drop(['id','ever_married','work_type'], axis=1)
display(df.head())
# Out:
#    gender   age  hypertension  heart_disease Residence_type  \
# 0    Male  67.0             0              1          Urban
# 2    Male  80.0             0              1          Rural
# 3  Female  49.0             0              0          Urban
# 4  Female  79.0             1              0          Rural
# 5    Male  81.0             0              0          Urban
#
#    avg_glucose_level   bmi   smoking_status  stroke
# 0             228.69  36.6  formerly smoked       1
# 2             105.92  32.5     never smoked       1
# 3             171.23  34.4           smokes       1
# 4             174.12  24.0     never smoked       1
# 5             186.21  29.0  formerly smoked       1

# %%
import matplotlib.pyplot as plt

for coluna in df.columns:
  fig,ax=plt.subplots()
  ax.scatter(df['stroke'],df[coluna])
  ax.set_xlabel('stroke')
  ax.set_ylabel(coluna)
  plt.show()

# %%
import seaborn as sns

for coluna in df.columns:
  sns.boxplot(df[coluna])
  plt.show()

# %%
df=df[df['avg_glucose_level'] < 250]
df=df[df['bmi'] < 50]

# %%
for coluna in df.columns:
  sns.boxplot(df[coluna])
  plt.show()

# %%
display(df.describe())
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4807.000000   4807.000000    4807.000000        4807.000000
# mean     42.704830      0.088829       0.049303         104.297485
# std      22.649516      0.284526       0.216523          42.901980
# min       0.080000      0.000000       0.000000          55.120000
# 25%      24.000000      0.000000       0.000000          76.955000
# 50%      44.000000      0.000000       0.000000          91.530000
# 75%      60.000000      0.000000       0.000000         112.955000
# max      82.000000      1.000000       1.000000         249.310000
#
#                bmi       stroke
# count  4807.000000  4807.000000
# mean     28.431579     0.042230
# std       7.013237     0.201135
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      27.900000     0.000000
# 75%      32.750000     0.000000
# max      49.900000     1.000000

# %%
df['age']=df['age'].astype(int)

# %%
df.dtypes
# Out:
# gender                object
# age                    int64
# hypertension           int64
# heart_disease          int64
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

codificador_gender=LabelEncoder()
codificador_residence_type=LabelEncoder()
codificador_smoking_status=LabelEncoder()

df['gender']=codificador_gender.fit_transform(df['gender'])
df['Residence_type']=codificador_residence_type.fit_transform(df['Residence_type'])
df['smoking_status']=codificador_smoking_status.fit_transform(df['smoking_status'])

display(df)
joblib.dump(codificador_gender,'Codificador_Gender.plk')
joblib.dump(codificador_residence_type,'Codificador_Residence_Type.plk')
joblib.dump(codificador_smoking_status,'Codificador_Smoking_Status.plk')
# Out:
#       gender  age  hypertension  heart_disease  Residence_type  \
# 0          1   67             0              1               1
# 2          1   80             0              1               0
# 3          0   49             0              0               1
# 4          0   79             1              0               0
# 5          1   81             0              0               1
# ...      ...  ...           ...            ...             ...
# 5104       0   13             0              0               0
# 5106       0   81             0              0               1
# 5107       0   35             0              0               0
# 5108       1   51             0              0               0
# 5109       0   44             0              0               1
#
#       avg_glucose_level   bmi  smoking_status  stroke
# 0                228.69  36.6               1       1
# 2                105.92  32.5               2       1
# ...

# %%
x=df.drop(['stroke'], axis=1)
y=df['stroke']

# %%
from sklearn.model_selection import train_test_split

x_treino,x_teste,y_treino,y_teste=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import joblib

modelo_RFC=RandomForestClassifier(max_depth=15)
modelo_RFC.fit(x_treino,y_treino)

modelo_KNN=KNeighborsClassifier()
modelo_KNN.fit(x_treino,y_treino)

joblib.dump(modelo_RFC,'Modelo_Ramdom_Forest_Classifier.plk')
# Out:
# ['Modelo_Ramdom_Forest_Classifier.plk']

# %%
from sklearn.metrics import accuracy_score

previsao_RFC=modelo_RFC.predict(x_teste)
previsao_KNN=modelo_KNN.predict(x_teste)

print(accuracy_score(y_teste,previsao_RFC))
print(accuracy_score(y_teste,previsao_KNN))
# Out:
# 0.956738768718802
# 0.9559068219633944
